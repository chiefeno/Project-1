# %%
# HOW TO BETTER ADVISE STUDENTS REGARDING THEIR GOALS, MAJORS AND SCHOOL CHOICES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# '/Users/jo./projects/dsi/projects/project_1'

# %%
pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/act_2017.csv')
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
act_2017 = pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/act_2017.csv')

# %%
pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/sat_2019_by_intended_college_major.csv')
# Out:
#                                  IntendedCollegeMajor TestTakers Percent  \
# 0   Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                   Architecture and Related Services     28,988      2%
# 2          Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 3                  Biological and Biomedical Sciences    155,834      8%
# 4   Business, Management, Marketing, and Related S...    221,523     12%
# 5     Communication, Journalism, and Related Programs     36,332      2%
# 6   Computer and Information Sciences and Support ...     79,736      4%
# 7                        Construction Trades, General      2,500      0%
# 8                                           Education     71,882      4%
# 9                                         Engineering    194,127     11%
# 10               Engineering Technologies/Technicians     33,595      2%
# 11            English Language and Literature/Letters     16,233      1%
# ...

# %%
intended_college_major = pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/sat_2019_by_intended_college_major.csv')

# %%
# Grades are in different format !!! SAT vs ACT

# %%
pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/sat_2017.csv')
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
sat_2017 = pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/sat_2017.csv')

# %%
pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/sat_act_by_college.csv')
# Out:
#                                     School Test Optional?  \
# 0                      Stanford University            Yes
# 1                          Harvard College            Yes
# 2                     Princeton University            Yes
# 3                      Columbia University            Yes
# 4                          Yale University            Yes
# ..                                     ...            ...
# 411  University of Texas Rio Grande Valley             No
# 412             University of South Dakota             No
# 413              University of Mississippi             No
# 414                  University of Wyoming             No
# 415            University of Texas El Paso             No
#
#     Applies to Class Year(s)  \
# 0                       2021
# 1                       2021
# 2                       2021
# 3                       2021
# 4                       2021
# ..                       ...
# 411                      NaN
# ...

# %%
# Test optional can be turned into booleans

# %%
# Is there a correlation between the number of applicants and the acceptance rate ?

# %%
sat_act_by_college = pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/sat_act_by_college.csv')

# %%
act_2018 = pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/act_2018.csv')

# %%
act_2019 = pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/act_2019.csv')

# %%
sat_2018 = pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/sat_2018.csv')

# %%
sat_2019 = pd.read_csv('/Users/jo./projects/dsi/projects/project_1/data/sat_2019.csv')

# %%
act_2017['date'] = '2017'

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite  date
# 0  National           60%     20.3  20.7     21.4     21.0      21.0  2017
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2  2017
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8  2017
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7  2017
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4  2017

# %%
act_2018['date'] = '2018'

# %%
act_2019['date'] = '2019'

# %%
sat_2017['date'] = '2017'

# %%
sat_2018['date'] = '2018'

# %%
sat_2019['date'] = '2019'

# %%
act_2018.head()
# Out:
#         State Participation  Composite  date
# 0     Alabama          100%       19.1  2018
# 1      Alaska           33%       20.8  2018
# 2     Arizona           66%       19.2  2018
# 3    Arkansas          100%       19.4  2018
# 4  California           27%       22.7  2018

# %%
act_2019.head()
# Out:
#         State Participation  Composite  date
# 0     Alabama          100%       18.9  2019
# 1      Alaska           38%       20.1  2019
# 2     Arizona           73%       19.0  2019
# 3    Arkansas          100%       19.3  2019
# 4  California           23%       22.6  2019

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite  date
# 0  National           60%     20.3  20.7     21.4     21.0      21.0  2017
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2  2017
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8  2017
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7  2017
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4  2017

# %%
new_act_2017 = act_2017

# %%
new_act_2017.drop(['English' , 'Math', 'Reading', 'Science'] , axis = 1, inplace= True)

# %%
new_act_2017.head()
# Out:
#       State Participation Composite  date
# 0  National           60%      21.0  2017
# 1   Alabama          100%      19.2  2017
# 2    Alaska           65%      19.8  2017
# 3   Arizona           62%      19.7  2017
# 4  Arkansas          100%      19.4  2017

# %%
import missingno as msno

# %%
msno.bar(new_act_2017);

# %%
msno.bar(act_2018);

# %%
msno.bar(act_2019);

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
#  3   date           52 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 1.8+ KB

# %%
new_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     object
#  3   date           52 non-null     object
# dtypes: object(4)
# memory usage: 1.8+ KB

# %%
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
#  3   date           52 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 1.8+ KB

# %%
new_act_2017['Composite'] = new_act_2017['Composite'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-b360a016ef35> in <module>
# ----> 1 new_act_2017['Composite'] = new_act_2017['Composite'].astype(int)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
# ...

# %%
new_act_2017['Composite'] = new_act_2017['Composite'].replace(['20.2x'],'20.2')

# %%
new_act_2017
# Out:
#                    State Participation Composite  date
# 0               National           60%      21.0  2017
# 1                Alabama          100%      19.2  2017
# 2                 Alaska           65%      19.8  2017
# 3                Arizona           62%      19.7  2017
# 4               Arkansas          100%      19.4  2017
# 5             California           31%      22.8  2017
# 6               Colorado          100%      20.8  2017
# 7            Connecticut           31%      25.2  2017
# 8               Delaware           18%      24.1  2017
# 9   District of Columbia           32%      24.2  2017
# 10               Florida           73%      19.8  2017
# 11               Georgia           55%      21.4  2017
# 12                Hawaii           90%      19.0  2017
# 13                 Idaho           38%      22.3  2017
# 14              Illinois           93%      21.4  2017
# 15               Indiana           35%      22.6  2017
# ...

# %%
new_act_2017['Composite'] = new_act_2017['Composite'].astype(float)

# %%
new_act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
#  3   date           52 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 1.8+ KB

# %%
pd.concat([new_act_2017, act_2018, act_2019])
# Out:
#             State Participation  Composite  date
# 0        National           60%       21.0  2017
# 1         Alabama          100%       19.2  2017
# 2          Alaska           65%       19.8  2017
# 3         Arizona           62%       19.7  2017
# 4        Arkansas          100%       19.4  2017
# ..            ...           ...        ...   ...
# 47     Washington           24%       22.1  2019
# 48  West Virginia           49%       20.8  2019
# 49      Wisconsin          100%       20.3  2019
# 50        Wyoming          100%       19.8  2019
# 51       National           52%       20.7  2019
#
# [156 rows x 4 columns]

# %%
act_1 = pd.concat([new_act_2017, act_2018, act_2019])

# %%
act_scores = pd.concat([new_act_2017, act_2018, act_2019])

# %%
act_scores.head()
# Out:
#       State Participation  Composite  date
# 0  National           60%       21.0  2017
# 1   Alabama          100%       19.2  2017
# 2    Alaska           65%       19.8  2017
# 3   Arizona           62%       19.7  2017
# 4  Arkansas          100%       19.4  2017

# %%
act_scores.groupby(['State', 'date']).apply(print)
# Out:
#      State Participation  Composite  date
# 1  Alabama          100%       19.2  2017
#      State Participation  Composite  date
# 0  Alabama          100%       19.1  2018
#      State Participation  Composite  date
# 0  Alabama          100%       18.9  2019
#     State Participation  Composite  date
# 2  Alaska           65%       19.8  2017
#     State Participation  Composite  date
# 1  Alaska           33%       20.8  2018
#     State Participation  Composite  date
# 1  Alaska           38%       20.1  2019
#      State Participation  Composite  date
# 3  Arizona           62%       19.7  2017
#      State Participation  Composite  date
# 2  Arizona           66%       19.2  2018
#      State Participation  Composite  date
# 2  Arizona           73%       19.0  2019
#       State Participation  Composite  date
# 4  Arkansas          100%       19.4  2017
#       State Participation  Composite  date
# 3  Arkansas          100%       19.4  2018
# ...

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055
#
#    date
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
#
#    date
# 0  2018
# 1  2018
# 2  2018
# 3  2018
# 4  2018

# %%
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total  date
# 0     Alabama                 7%   583   560   1143  2019
# 1      Alaska                41%   556   541   1097  2019
# 2     Arizona                31%   569   565   1134  2019
# 3    Arkansas                 6%   582   559   1141  2019
# 4  California                63%   534   531   1065  2019

# %%
sat_2019.columns = ['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math', 'Total', 'date']

# %%
sat_2019.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 0     Alabama            7%                                 583   560   1143
# 1      Alaska           41%                                 556   541   1097
# 2     Arizona           31%                                 569   565   1134
# 3    Arkansas            6%                                 582   559   1141
# 4  California           63%                                 534   531   1065
#
#    date
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
#  5   date                                51 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 2.5+ KB

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
#  5   date                                51 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 2.5+ KB

# %%
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               53 non-null     object
#  1   Participation                       53 non-null     object
#  2   Evidence-Based Reading and Writing  53 non-null     int64
#  3   Math                                53 non-null     int64
#  4   Total                               53 non-null     int64
#  5   date                                53 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 2.6+ KB

# %%
sat_2019.iloc[52]
# Out:
# State                                 Wyoming
# Participation                              3%
# Evidence-Based Reading and Writing        623
# Math                                      615
# Total                                    1238
# date                                     2019
# Name: 52, dtype: object

# %%
sat_2018.iloc[50]
# Out:
# State                                 Wyoming
# Participation                              3%
# Evidence-Based Reading and Writing        633
# Math                                      625
# Total                                    1257
# date                                     2018
# Name: 50, dtype: object

# %%
sat_2019['State'].count()
# Out:
# 53

# %%
what_is_diff = pd.concat([sat_2018 , sat_2019]).drop_duplicates(keep=False)

# %%
del what_is_diff

# %%
del diff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-3694a8dafd5e> in <module>
# ----> 1 del diff
#
# NameError: name 'diff' is not defined

# %%
sat_2019.head(53)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            7%                                 583
# 1                 Alaska           41%                                 556
# 2                Arizona           31%                                 569
# 3               Arkansas            6%                                 582
# 4             California           63%                                 534
# 5               Colorado          100%                                 518
# 6            Connecticut          100%                                 529
# 7               Delaware          100%                                 499
# 8   District of Columbia           94%                                 495
# 9                Florida          100%                                 516
# 10               Georgia           71%                                 538
# ...

# %%
sat_2018.head(52)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
# two extra values on sat_2019 : Puerto Rico and Virgin Islands with no participation rate . I decide to drop those two values for convenience

# %%
sat_2019.iloc[39]
# Out:
# State                                 Puerto Rico
# Participation                                   —
# Evidence-Based Reading and Writing            483
# Math                                          462
# Total                                         944
# date                                         2019
# Name: 39, dtype: object

# %%
sat_2019.drop(sat_2019.index[39], inplace=True)

# %%
sat_2019.head(53)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            7%                                 583
# 1                 Alaska           41%                                 556
# 2                Arizona           31%                                 569
# 3               Arkansas            6%                                 582
# 4             California           63%                                 534
# 5               Colorado          100%                                 518
# 6            Connecticut          100%                                 529
# 7               Delaware          100%                                 499
# 8   District of Columbia           94%                                 495
# 9                Florida          100%                                 516
# 10               Georgia           71%                                 538
# ...

# %%
sat_2019.iloc[46]
# Out:
# State                                 Virgin Islands
# Participation                                      —
# Evidence-Based Reading and Writing               490
# Math                                             445
# Total                                            935
# date                                            2019
# Name: 47, dtype: object

# %%
sat_2019.drop(sat_2019.index[46], inplace=True)

# %%
sat_2019.head(53)
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            7%                                 583
# 1                 Alaska           41%                                 556
# 2                Arizona           31%                                 569
# 3               Arkansas            6%                                 582
# 4             California           63%                                 534
# 5               Colorado          100%                                 518
# 6            Connecticut          100%                                 529
# 7               Delaware          100%                                 499
# 8   District of Columbia           94%                                 495
# 9                Florida          100%                                 516
# 10               Georgia           71%                                 538
# ...

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
#  5   date                                51 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 2.5+ KB

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
#  5   date                                51 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 2.5+ KB

# %%
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
#  5   date                                51 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 2.8+ KB

# %%
pd.concat([sat_2017, sat_2018, sat_2019])
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 0         Alabama            5%                                 593   572
# 1          Alaska           38%                                 547   533
# 2         Arizona           30%                                 563   553
# 3        Arkansas            3%                                 614   594
# 4      California           53%                                 531   524
# ..            ...           ...                                 ...   ...
# 48       Virginia           68%                                 567   551
# 49     Washington           70%                                 539   535
# 50  West Virginia           99%                                 483   460
# 51      Wisconsin            3%                                 635   648
# 52        Wyoming            3%                                 623   615
#
#     Total  date
# 0    1165  2017
# 1    1080  2017
# 2    1116  2017
# ...

# %%
sat_scores = pd.concat([sat_2017, sat_2018, sat_2019])

# %%
msno.bar(sat_act_by_college);

# %%
# 26 missing values in the Applies to class Years category. 
# establish range for top tier schools ; average school based on national average grade in both SAT and ACT
# Which are the school with the most applicants ? What about their acceptance rate ?
# How many colleges have an optional test ?
#

# %%
sat_act_by_college.tail(26)
# Out:
#                                    School Test Optional?  \
# 390              UnitedStatesNavalAcademy             No
# 391           UnitedStatesMilitaryAcademy             No
# 392           UnitedStatesAirForceAcademy             No
# 393         UnitedStatesCoastGuardAcademy             No
# 394   UnitedStatesMerchantMaritimeAcademy             No
# 395                      HowardUniversity             No
# 396                FloridaStateUniversity             No
# 397                      HillsdaleCollege             No
# 398            UniversityofCentralFlorida             No
# 399                   UniversityofFlorida             No
# 400              UniversityofSouthFlorida             No
# 401                   GallaudetUniversity             No
# 402                  FloridaInternational             No
# 403                      MorehouseCollege             No
# 404                   UniversityofAlabama             No
# ...

# %%
sat_act_by_college['Applies to Class Year(s)'].fillna('Not Provided', inplace=True)

# %%
sat_act_by_college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   School                          416 non-null    object
#  1   Test Optional?                  416 non-null    object
#  2   Applies to Class Year(s)        416 non-null    object
#  3   Policy Details                  416 non-null    object
#  4   Number of Applicants            416 non-null    int64
#  5   Accept Rate                     416 non-null    object
#  6   SAT Total 25th-75th Percentile  416 non-null    object
#  7   ACT Total 25th-75th Percentile  416 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 26.1+ KB

# %%
sat_act_by_college['Test_is_required'] = np.where(sat_act_by_college['Test Optional?'].str.contains('No'), 1, 0)

# %%
sat_act_by_college.head()
# Out:
#                 School Test Optional? Applies to Class Year(s)  \
# 0   StanfordUniversity            Yes                     2021
# 1       HarvardCollege            Yes                     2021
# 2  PrincetonUniversity            Yes                     2021
# 3   ColumbiaUniversity            Yes                     2021
# 4       YaleUniversity            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanfordhasadoptedaone-yeartestoptionalpolicyf...                 47452
# 1  Harvardhasadoptedaone-yeartestoptionalpolicyfo...                 42749
# 2  Princetonhasadoptedaone-yeartestoptionalpolicy...                 35370
# 3  Columbiahasadoptedaone-yeartestoptionalpolicyf...                 40203
# 4  Yalehasadoptedaone-yeartestoptionalpolicyforth...                 36844
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile  \
# ...

# %%
sat_act_by_college.groupby('Test_is_required').count()
# Out:
#                   School  Test Optional?  Applies to Class Year(s)  \
# Test_is_required
# 0                    390             390                       390
# 1                     26              26                        26
#
#                   Policy Details  Number of Applicants  Accept Rate  \
# Test_is_required
# 0                            390                   390          390
# 1                             26                    26           26
#
#                   SAT Total 25th-75th Percentile  \
# Test_is_required
# 0                                            390
# 1                                             26
#
#                   ACT Total 25th-75th Percentile
# Test_is_required
# 0                                            390
# 1                                             26

# %%
# Only 26 colleges requires a test; all the other colleges have the test as optional (intro chart ?)

# %%
# Divide the Percentile in two columns for SAT and ACT

# %%
percentile_1 = sat_act_by_college['SAT Total 25th-75th Percentile'].str.split('-', expand=True)

# %%
percentile_1.head()
# Out:
#       0     1     2
# 0  1440  1570  None
# 1  1460  1580  None
# 2  1440  1570  None
# 3  1450  1560  None
# 4  1460  1570  None

# %%
percentile_1.drop(2 , axis=1)
# Out:
#         0     1
# 0    1440  1570
# 1    1460  1580
# 2    1440  1570
# 3    1450  1560
# 4    1460  1570
# ..    ...   ...
# 411   950  1130
# 412   990  1180
# 413  1050  1270
# 414  1060  1280
# 415   820  1050
#
# [416 rows x 2 columns]

# %%
percentile_1.columns = ['SAT Total 25th Percentile' , 'SAT Total 75th Percentile' , 'i']

# %%
percentile_1.head()
# Out:
#   SAT Total 25th Percentile SAT Total 75th Percentile     i
# 0                      1440                      1570  None
# 1                      1460                      1580  None
# 2                      1440                      1570  None
# 3                      1450                      1560  None
# 4                      1460                      1570  None

# %%
percentile_1.drop('i' , axis=1)
# Out:
#     SAT Total 25th Percentile SAT Total 75th Percentile
# 0                        1440                      1570
# 1                        1460                      1580
# 2                        1440                      1570
# 3                        1450                      1560
# 4                        1460                      1570
# ..                        ...                       ...
# 411                       950                      1130
# 412                       990                      1180
# 413                      1050                      1270
# 414                      1060                      1280
# 415                       820                      1050
#
# [416 rows x 2 columns]

# %%
percentile_2 = sat_act_by_college['ACT Total 25th-75th Percentile'].str.split('-', expand=True)

# %%
percentile_2.head()
# Out:
#     0   1     2
# 0  32  35  None
# 1  33  35  None
# 2  32  35  None
# 3  33  35  None
# 4  33  35  None

# %%
percentile_2.drop(2 , axis=1)
# Out:
#       0   1
# 0    32  35
# 1    33  35
# 2    32  35
# 3    33  35
# 4    33  35
# ..   ..  ..
# 411  17  22
# 412  19  25
# 413  21  29
# 414  22  28
# 415  17  23
#
# [416 rows x 2 columns]

# %%
percentile_2.columns = ['ACT Total 25th Percentile' , 'ACT Total 75th Percentile' , 'i']

# %%
percentile_2.head()
# Out:
#   ACT Total 25th Percentile ACT Total 75th Percentile     i
# 0                        32                        35  None
# 1                        33                        35  None
# 2                        32                        35  None
# 3                        33                        35  None
# 4                        33                        35  None

# %%
percentile_1.drop('i' , axis=1 , inplace=True)

# %%
percentile_1.head()
# Out:
#   SAT Total 25th Percentile SAT Total 75th Percentile
# 0                      1440                      1570
# 1                      1460                      1580
# 2                      1440                      1570
# 3                      1450                      1560
# 4                      1460                      1570

# %%
percentile_2.drop('i' , axis=1 , inplace=True)

# %%
percentile_2.head()
# Out:
#   ACT Total 25th Percentile ACT Total 75th Percentile
# 0                        32                        35
# 1                        33                        35
# 2                        32                        35
# 3                        33                        35
# 4                        33                        35

# %%
sat_act_by_college = sat_act_by_college.join(percentile_1)

# %%
sat_act_by_college.head()
# Out:
#                 School Test Optional? Applies to Class Year(s)  \
# 0   StanfordUniversity            Yes                     2021
# 1       HarvardCollege            Yes                     2021
# 2  PrincetonUniversity            Yes                     2021
# 3   ColumbiaUniversity            Yes                     2021
# 4       YaleUniversity            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanfordhasadoptedaone-yeartestoptionalpolicyf...                 47452
# 1  Harvardhasadoptedaone-yeartestoptionalpolicyfo...                 42749
# 2  Princetonhasadoptedaone-yeartestoptionalpolicy...                 35370
# 3  Columbiahasadoptedaone-yeartestoptionalpolicyf...                 40203
# 4  Yalehasadoptedaone-yeartestoptionalpolicyforth...                 36844
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile  \
# ...

# %%
sat_act_by_college = sat_act_by_college.join(percentile_2)

# %%
sat_act_by_college.head()
# Out:
#                 School Test Optional? Applies to Class Year(s)  \
# 0   StanfordUniversity            Yes                     2021
# 1       HarvardCollege            Yes                     2021
# 2  PrincetonUniversity            Yes                     2021
# 3   ColumbiaUniversity            Yes                     2021
# 4       YaleUniversity            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanfordhasadoptedaone-yeartestoptionalpolicyf...                 47452
# 1  Harvardhasadoptedaone-yeartestoptionalpolicyfo...                 42749
# 2  Princetonhasadoptedaone-yeartestoptionalpolicy...                 35370
# 3  Columbiahasadoptedaone-yeartestoptionalpolicyf...                 40203
# 4  Yalehasadoptedaone-yeartestoptionalpolicyforth...                 36844
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile  \
# ...

# %%
sat_act_by_college.drop(['SAT Total 25th-75th Percentile' , 'ACT Total 25th-75th Percentile'] , axis=1 , inplace=True)

# %%
sat_act_by_college.head()
# Out:
#                 School Test Optional? Applies to Class Year(s)  \
# 0   StanfordUniversity            Yes                     2021
# 1       HarvardCollege            Yes                     2021
# 2  PrincetonUniversity            Yes                     2021
# 3   ColumbiaUniversity            Yes                     2021
# 4       YaleUniversity            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanfordhasadoptedaone-yeartestoptionalpolicyf...                 47452
# 1  Harvardhasadoptedaone-yeartestoptionalpolicyfo...                 42749
# 2  Princetonhasadoptedaone-yeartestoptionalpolicy...                 35370
# 3  Columbiahasadoptedaone-yeartestoptionalpolicyf...                 40203
# 4  Yalehasadoptedaone-yeartestoptionalpolicyforth...                 36844
#
#   Accept Rate  Test_is_required SAT Total 25th Percentile  \
# 0        4.3%                 0                      1440
# ...

# %%
sat_act_by_college = sat_act_by_college.loc[:, ['School', 'Test Optional?', 'Applies to Class Year(s)', 'Policy Details', 'Number of Applicants', 'Accept Rate', 'SAT Total 25th Percentile', 'SAT Total 75th Percentile', 'ACT Total 25th Percentile', 'ACT Total 75th Percentile', 'Test_is_required']]

# %%
sat_act_by_college.head()
# Out:
#                 School Test Optional? Applies to Class Year(s)  \
# 0   StanfordUniversity            Yes                     2021
# 1       HarvardCollege            Yes                     2021
# 2  PrincetonUniversity            Yes                     2021
# 3   ColumbiaUniversity            Yes                     2021
# 4       YaleUniversity            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanfordhasadoptedaone-yeartestoptionalpolicyf...                 47452
# 1  Harvardhasadoptedaone-yeartestoptionalpolicyfo...                 42749
# 2  Princetonhasadoptedaone-yeartestoptionalpolicy...                 35370
# 3  Columbiahasadoptedaone-yeartestoptionalpolicyf...                 40203
# 4  Yalehasadoptedaone-yeartestoptionalpolicyforth...                 36844
#
#   Accept Rate SAT Total 25th Percentile SAT Total 75th Percentile  \
# ...

# %%
# Now let's convert some data type; percentile to int64 and percentages to float !

# %%
sat_act_by_college[['SAT Total 25th Percentile']] = sat_act_by_college[['SAT Total 25th Percentile']].replace('\u200b', ' ')

# %%
sat_act_by_college.replace('(\u200b\u200b)','',regex=True, inplace = True)

# %%
# I can't believe this !!! Stack overflow : most valuable website !!!!

# %%
sat_act_by_college['SAT Total 25th Percentile'] = sat_act_by_college['SAT Total 25th Percentile'].astype(float)

# %%
sat_act_by_college['SAT Total 25th Percentile'] = sat_act_by_college['SAT Total 25th Percentile'].astype(int)

# %%
sat_act_by_college[['SAT Total 25th Percentile']].count()

# %%
print (sat_act_by_college['SAT Total 25th Percentile'].dtypes)

# %%
sat_act_by_college.loc[sat_act_by_college['SAT Total 25th Percentile'] == '1142.5']

# %%
sat_act_by_college[sat_act_by_college['SAT Total 25th Percentile'].str.contains(" ")]

# %%
sat_act_by_college.replace(' ','',regex=True, inplace = True)

# %%
sat_act_by_college[sat_act_by_college['SAT Total 25th Percentile'].str.contains(" ")]
# Out:
# Empty DataFrame
# Columns: [School, Test Optional?, Applies to Class Year(s), Policy Details, Number of Applicants, Accept Rate, SAT Total 25th Percentile, SAT Total 75th Percentile, ACT Total 25th Percentile, ACT Total 75th Percentile, Test_is_required]
# Index: []

# %%
sat_act_by_college['SAT Total 25th Percentile'] = sat_act_by_college['SAT Total 25th Percentile'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-5b15561fdcdd> in <module>
# ----> 1 sat_act_by_college['SAT Total 25th Percentile'] = sat_act_by_college['SAT Total 25th Percentile'].astype(float)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# ...

# %%
sat_act_by_college['SAT Total 25th Percentile'].sort_values(ascending=True)
# Out:
# 383
# 254
# 405
# 305
# 386
#         ...
# 353       990
# 7      ​​1440
# 8      ​​1490
# 6      ​​1500
# 5      ​​1530
# Name: SAT Total 25th Percentile, Length: 416, dtype: object

# %%
sat_act_by_college.iloc[383]
# Out:
# School                                                      UniversityofKansas
# Test Optional?                                                            Yes*
# Applies to Class Year(s)                                   All/PermanentPolicy
# Policy Details               TheUniversityofKansasrequireseithertheSATorthe...
# Number of Applicants                                                     15093
# Accept Rate                                                              93.1%
# SAT Total 25th Percentile
# SAT Total 75th Percentile
# ACT Total 25th Percentile                                                   23
# ACT Total 75th Percentile                                                   29
# Test_is_required                                                             0
# Name: 383, dtype: object

# %%
# SAT scores Missing !!!

# %%
percentile_1.sort_values(by = ['SAT Total 25th Percentile'], ascending=True)
# Out:
#     SAT Total 25th Percentile SAT Total 75th Percentile
# 383
# 254
# 405
# 305
# 386
# ..                        ...                       ...
# 353                       990                      1210
# 7                      ​​1440                      1570
# 8                      ​​1490                      1570
# 6                      ​​1500                      1570
# 5                      ​​1530                      1560
#
# [416 rows x 2 columns]

# %%
sat_act_by_college[sat_act_by_college['SAT Total 25th Percentile'].str.contains("")]
# Out:
#                                School Test Optional? Applies to Class Year(s)  \
# 0                  StanfordUniversity            Yes                     2021
# 1                      HarvardCollege            Yes                     2021
# 2                 PrincetonUniversity            Yes                     2021
# 3                  ColumbiaUniversity            Yes                     2021
# 4                      YaleUniversity            Yes                     2021
# ..                                ...            ...                      ...
# 411  UniversityofTexasRioGrandeValley             No              NotProvided
# 412           UniversityofSouthDakota             No              NotProvided
# 413           UniversityofMississippi             No              NotProvided
# 414               UniversityofWyoming             No              NotProvided
# 415           UniversityofTexasElPaso             No              NotProvided
#
# ...

# %%
str_len = (sat_act_by_college['SAT Total 25th Percentile'].str.len() < 2)

# %%
missing_sat = sat_act_by_college.loc[str_len]

# %%
missing_sat.head(20)
# Out:
#                            School Test Optional? Applies to Class Year(s)  \
# 254       GustavusAdolphusCollege            Yes      All/PermanentPolicy
# 305                     BallState            Yes      All/PermanentPolicy
# 375                    WeberState            Yes      All/PermanentPolicy
# 383            UniversityofKansas           Yes*      All/PermanentPolicy
# 386         KansasStateUniversity           Yes*      All/PermanentPolicy
# 405  MilwaukeeSchoolofEngineering             No              NotProvided
#
#                                         Policy Details  Number of Applicants  \
# 254  GustavusAdolphusCollegeoffersatestoptionalpoli...                  4957
# 305  BallStateUniversityoffersatestoptionalpolicywh...                 23305
# 375  WeberStateUniversityoffersatestoptionalpolicyw...                  6853
# 383  TheUniversityofKansasrequireseithertheSATorthe...                 15093
# ...

# %%
# First of all Ball state university out ! Should I replace the other missing values with NaN or out them too ??!!!

# %%
sat_act_by_college.loc[254]
# Out:
# School                                                 GustavusAdolphusCollege
# Test Optional?                                                             Yes
# Applies to Class Year(s)                                   All/PermanentPolicy
# Policy Details               GustavusAdolphusCollegeoffersatestoptionalpoli...
# Number of Applicants                                                      4957
# Accept Rate                                                              69.2%
# SAT Total 25th Percentile
# SAT Total 75th Percentile
# ACT Total 25th Percentile                                                   25
# ACT Total 75th Percentile                                                   30
# Test_is_required                                                             0
# Name: 254, dtype: object

# %%
sat_act_by_college.drop(sat_act_by_college.index[254], inplace=True)

# %%
# only 5 values left so I just drop them

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
str_len = (sat_act_by_college['SAT Total 25th Percentile'].str.len() < 2)

# %%
missing_sat = sat_act_by_college.loc[str_len]

# %%
missing_sat.head(20)
# Out:
#      index                        School Test Optional?  \
# 304    305                     BallState            Yes
# 374    375                    WeberState            Yes
# 382    383            UniversityofKansas           Yes*
# 385    386         KansasStateUniversity           Yes*
# 404    405  MilwaukeeSchoolofEngineering             No
#
#     Applies to Class Year(s)  \
# 304      All/PermanentPolicy
# 374      All/PermanentPolicy
# 382      All/PermanentPolicy
# 385      All/PermanentPolicy
# 404              NotProvided
#
#                                         Policy Details  Number of Applicants  \
# 304  BallStateUniversityoffersatestoptionalpolicywh...                 23305
# 374  WeberStateUniversityoffersatestoptionalpolicyw...                  6853
# 382  TheUniversityofKansasrequireseithertheSATorthe...                 15093
# 385  KansasStaterequireseithertheSATorACT.Howeverth...                  8140
# ...

# %%
sat_act_by_college.drop(sat_act_by_college.index[304], inplace=True)

# %%
sat_act_by_college.drop('index' , axis = 1 , inplace=True)

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
str_len = (sat_act_by_college['SAT Total 25th Percentile'].str.len() < 2)

# %%
missing_sat = sat_act_by_college.loc[str_len]

# %%
missing_sat.head(20)
# Out:
#      index                        School Test Optional?  \
# 373    374                    WeberState            Yes
# 381    382            UniversityofKansas           Yes*
# 384    385         KansasStateUniversity           Yes*
# 403    404  MilwaukeeSchoolofEngineering             No
#
#     Applies to Class Year(s)  \
# 373      All/PermanentPolicy
# 381      All/PermanentPolicy
# 384      All/PermanentPolicy
# 403              NotProvided
#
#                                         Policy Details  Number of Applicants  \
# 373  WeberStateUniversityoffersatestoptionalpolicyw...                  6853
# 381  TheUniversityofKansasrequireseithertheSATorthe...                 15093
# 384  KansasStaterequireseithertheSATorACT.Howeverth...                  8140
# 403  TheMilwaukeeSchoolofEngineeringrequireseithert...                  3552
#
#     Accept Rate SAT Total 25th Percentile SAT Total 75th Percentile  \
# 373       89.1%
# 381       93.1%
# 384       95.7%
# 403       61.7%
# ...

# %%
sat_act_by_college.drop(sat_act_by_college.index[373], inplace=True)

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
str_len = (sat_act_by_college['SAT Total 25th Percentile'].str.len() < 2)

# %%
missing_sat = sat_act_by_college.loc[str_len]

# %%
missing_sat.head(20)
# Out:
#      level_0  index                        School Test Optional?  \
# 380      381    382            UniversityofKansas           Yes*
# 383      384    385         KansasStateUniversity           Yes*
# 402      403    404  MilwaukeeSchoolofEngineering             No
#
#     Applies to Class Year(s)  \
# 380      All/PermanentPolicy
# 383      All/PermanentPolicy
# 402              NotProvided
#
#                                         Policy Details  Number of Applicants  \
# 380  TheUniversityofKansasrequireseithertheSATorthe...                 15093
# 383  KansasStaterequireseithertheSATorACT.Howeverth...                  8140
# 402  TheMilwaukeeSchoolofEngineeringrequireseithert...                  3552
#
#     Accept Rate SAT Total 25th Percentile SAT Total 75th Percentile  \
# 380       93.1%
# 383       95.7%
# 402       61.7%
#
#     ACT Total 25th Percentile ACT Total 75th Percentile  Test_is_required
# ...

# %%
sat_act_by_college.drop(sat_act_by_college.index[380], inplace=True)

# %%
sat_act_by_college.drop('index' , axis = 1 , inplace=True)

# %%
sat_act_by_college.drop('level_0' , axis = 1 , inplace=True)

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
str_len = (sat_act_by_college['SAT Total 25th Percentile'].str.len() < 2)

# %%
missing_sat = sat_act_by_college.loc[str_len]

# %%
missing_sat.head(20)
# Out:
#      index                        School Test Optional?  \
# 382    383         KansasStateUniversity           Yes*
# 401    402  MilwaukeeSchoolofEngineering             No
#
#     Applies to Class Year(s)  \
# 382      All/PermanentPolicy
# 401              NotProvided
#
#                                         Policy Details  Number of Applicants  \
# 382  KansasStaterequireseithertheSATorACT.Howeverth...                  8140
# 401  TheMilwaukeeSchoolofEngineeringrequireseithert...                  3552
#
#     Accept Rate SAT Total 25th Percentile SAT Total 75th Percentile  \
# 382       95.7%
# 401       61.7%
#
#     ACT Total 25th Percentile ACT Total 75th Percentile  Test_is_required
# 382                        22                        28                 0
# 401                        25                        30                 1

# %%
sat_act_by_college.drop(sat_act_by_college.index[383], inplace=True)

# %%
sat_act_by_college.drop('index' , axis = 1 , inplace=True)

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
str_len = (sat_act_by_college['SAT Total 25th Percentile'].str.len() < 2)

# %%
missing_sat = sat_act_by_college.loc[str_len]

# %%
missing_sat.head(20)
# Out:
#      index                        School Test Optional?  \
# 381    382         KansasStateUniversity           Yes*
# 399    401  MilwaukeeSchoolofEngineering             No
#
#     Applies to Class Year(s)  \
# 381      All/PermanentPolicy
# 399              NotProvided
#
#                                         Policy Details  Number of Applicants  \
# 381  KansasStaterequireseithertheSATorACT.Howeverth...                  8140
# 399  TheMilwaukeeSchoolofEngineeringrequireseithert...                  3552
#
#     Accept Rate SAT Total 25th Percentile SAT Total 75th Percentile  \
# 381       95.7%
# 399       61.7%
#
#     ACT Total 25th Percentile ACT Total 75th Percentile  Test_is_required
# 381                        22                        28                 0
# 399                        25                        30                 1

# %%
sat_act_by_college.drop(sat_act_by_college.index[381], inplace=True)

# %%
sat_act_by_college.drop('index' , axis = 1 , inplace=True)

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
str_len = (sat_act_by_college['SAT Total 25th Percentile'].str.len() < 2)

# %%
missing_sat = sat_act_by_college.loc[str_len]

# %%
missing_sat.head(20)
# Out:
#      index                        School Test Optional?  \
# 398    399  MilwaukeeSchoolofEngineering             No
#
#     Applies to Class Year(s)  \
# 398              NotProvided
#
#                                         Policy Details  Number of Applicants  \
# 398  TheMilwaukeeSchoolofEngineeringrequireseithert...                  3552
#
#     Accept Rate SAT Total 25th Percentile SAT Total 75th Percentile  \
# 398       61.7%
#
#     ACT Total 25th Percentile ACT Total 75th Percentile  Test_is_required
# 398                        25                        30                 1

# %%
sat_act_by_college.drop(sat_act_by_college.index[398], inplace=True)

# %%
sat_act_by_college.drop('index' , axis = 1 , inplace=True)

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
sat_act_by_college.drop('index' , axis = 1 , inplace=True)

# %%
sat_act_by_college['SAT Total 25th Percentile'] = sat_act_by_college['SAT Total 25th Percentile'].astype(float)

# %%
sat_act_by_college['SAT Total 75th Percentile'] = sat_act_by_college['SAT Total 75th Percentile'].astype(float)

# %%
str_len_2 = (sat_act_by_college['ACT Total 25th Percentile'].str.len() < 2)

# %%
missing_act = sat_act_by_college.loc[str_len_2]

# %%
missing_act.head(20)
# Out:
#                              School Test Optional? Applies to Class Year(s)  \
# 60   UniversityofCalifornia—​Irvine        Yes(TB)         2021202220232024
# 93                     CUNY--Hunter        Yes(TB)                     2021
# 114             CUNY--BaruchCollege        Yes(TB)                     2021
# 242                DePaulUniversity            Yes      All/PermanentPolicy
# 260                  MontclairState            Yes      All/PermanentPolicy
#
#                                         Policy Details  Number of Applicants  \
# 60   UCIhasadoptedafour-yeartestblindpolicybeginnin...                 95568
# 93   TheCUNYsystemhasadoptedaone-yearTestBlindpolic...                 31030
# 114  TheCUNYsystemhasadoptedaone-yearTestBlindpolic...                 20303
# 242  DePaulUniversityoffersatestoptionalpolicywhich...                 26895
# 260  MontclairStateoffersatestoptionalpolicywhichal...                 14324
#
# ...

# %%
# Same; I delete those rows for convenience

# %%
sat_act_by_college.drop(sat_act_by_college.index[60], inplace=True)

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
str_len_2 = (sat_act_by_college['ACT Total 25th Percentile'].str.len() < 2)

# %%
missing_act = sat_act_by_college.loc[str_len_2]

# %%
missing_act.head(20)
# Out:
#      index               School Test Optional? Applies to Class Year(s)  \
# 92      93         CUNY--Hunter        Yes(TB)                     2021
# 113    114  CUNY--BaruchCollege        Yes(TB)                     2021
# 241    242     DePaulUniversity            Yes      All/PermanentPolicy
# 259    260       MontclairState            Yes      All/PermanentPolicy
#
#                                         Policy Details  Number of Applicants  \
# 92   TheCUNYsystemhasadoptedaone-yearTestBlindpolic...                 31030
# 113  TheCUNYsystemhasadoptedaone-yearTestBlindpolic...                 20303
# 241  DePaulUniversityoffersatestoptionalpolicywhich...                 26895
# 259  MontclairStateoffersatestoptionalpolicywhichal...                 14324
#
#     Accept Rate  SAT Total 25th Percentile  SAT Total 75th Percentile  \
# 92        36.4%                     1090.0                     1260.0
# 113       43.4%                     1130.0                     1330.0
# ...

# %%
sat_act_by_college.drop(sat_act_by_college.index[92], inplace=True)

# %%
sat_act_by_college.drop('index' , axis = 1 , inplace=True)

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
str_len_2 = (sat_act_by_college['ACT Total 25th Percentile'].str.len() < 2)

# %%
missing_act = sat_act_by_college.loc[str_len_2]

# %%
missing_act.head(20)
# Out:
#      index               School Test Optional? Applies to Class Year(s)  \
# 112    113  CUNY--BaruchCollege        Yes(TB)                     2021
# 240    241     DePaulUniversity            Yes      All/PermanentPolicy
# 258    259       MontclairState            Yes      All/PermanentPolicy
#
#                                         Policy Details  Number of Applicants  \
# 112  TheCUNYsystemhasadoptedaone-yearTestBlindpolic...                 20303
# 240  DePaulUniversityoffersatestoptionalpolicywhich...                 26895
# 258  MontclairStateoffersatestoptionalpolicywhichal...                 14324
#
#     Accept Rate  SAT Total 25th Percentile  SAT Total 75th Percentile  \
# 112       43.4%                     1130.0                     1330.0
# 240       68.2%                     1070.0                     1290.0
# 258       70.9%                      990.0                     1170.0
#
#     ACT Total 25th Percentile ACT Total 75th Percentile  Test_is_required
# ...

# %%
sat_act_by_college.drop(sat_act_by_college.index[112], inplace=True)

# %%
sat_act_by_college.drop('index' , axis = 1 , inplace=True)

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
str_len_2 = (sat_act_by_college['ACT Total 25th Percentile'].str.len() < 2)

# %%
missing_act = sat_act_by_college.loc[str_len_2]

# %%
missing_act.head(20)
# Out:
#      index            School Test Optional? Applies to Class Year(s)  \
# 239    240  DePaulUniversity            Yes      All/PermanentPolicy
# 257    258    MontclairState            Yes      All/PermanentPolicy
#
#                                         Policy Details  Number of Applicants  \
# 239  DePaulUniversityoffersatestoptionalpolicywhich...                 26895
# 257  MontclairStateoffersatestoptionalpolicywhichal...                 14324
#
#     Accept Rate  SAT Total 25th Percentile  SAT Total 75th Percentile  \
# 239       68.2%                     1070.0                     1290.0
# 257       70.9%                      990.0                     1170.0
#
#     ACT Total 25th Percentile ACT Total 75th Percentile  Test_is_required
# 239                                                                     0
# 257                                                                     0

# %%
sat_act_by_college.drop(sat_act_by_college.index[239], inplace=True)

# %%
sat_act_by_college.drop('index' , axis = 1 , inplace=True)

# %%
sat_act_by_college = sat_act_by_college.reset_index()

# %%
str_len_2 = (sat_act_by_college['ACT Total 25th Percentile'].str.len() < 2)

# %%
missing_act = sat_act_by_college.loc[str_len_2]

# %%
missing_act.head(20)
# Out:
#      index          School Test Optional? Applies to Class Year(s)  \
# 256    257  MontclairState            Yes      All/PermanentPolicy
#
#                                         Policy Details  Number of Applicants  \
# 256  MontclairStateoffersatestoptionalpolicywhichal...                 14324
#
#     Accept Rate  SAT Total 25th Percentile  SAT Total 75th Percentile  \
# 256       70.9%                      990.0                     1170.0
#
#     ACT Total 25th Percentile ACT Total 75th Percentile  Test_is_required
# 256                                                                     0

# %%
sat_act_by_college.drop(sat_act_by_college.index[256], inplace=True)

# %%
sat_act_by_college.drop('index' , axis = 1 , inplace=True)

# %%
sat_act_by_college['ACT Total 25th Percentile'] = sat_act_by_college['ACT Total 25th Percentile'].astype(int)

# %%
sat_act_by_college['ACT Total 75th Percentile'] = sat_act_by_college['ACT Total 75th Percentile'].astype(int)

# %%
sat_act_by_college.head()
# Out:
#                 School Test Optional? Applies to Class Year(s)  \
# 0   StanfordUniversity            Yes                     2021
# 1       HarvardCollege            Yes                     2021
# 2  PrincetonUniversity            Yes                     2021
# 3   ColumbiaUniversity            Yes                     2021
# 4       YaleUniversity            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanfordhasadoptedaone-yeartestoptionalpolicyf...                 47452
# 1  Harvardhasadoptedaone-yeartestoptionalpolicyfo...                 42749
# 2  Princetonhasadoptedaone-yeartestoptionalpolicy...                 35370
# 3  Columbiahasadoptedaone-yeartestoptionalpolicyf...                 40203
# 4  Yalehasadoptedaone-yeartestoptionalpolicyforth...                 36844
#
#   Accept Rate  SAT Total 25th Percentile  SAT Total 75th Percentile  \
# ...

# %%
sat_act_by_college['Accept Rate'].replace('%','',regex=True,inplace=True)

# %%
sat_act_by_college['Accept Rate'] = sat_act_by_college['Accept Rate'].astype(float)

# %%
sat_act_by_college['Accept Rate'] = sat_act_by_college['Accept Rate'].div(100)

# %%
sat_act_by_college.head()
# Out:
#                 School Test Optional? Applies to Class Year(s)  \
# 0   StanfordUniversity            Yes                     2021
# 1       HarvardCollege            Yes                     2021
# 2  PrincetonUniversity            Yes                     2021
# 3   ColumbiaUniversity            Yes                     2021
# 4       YaleUniversity            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanfordhasadoptedaone-yeartestoptionalpolicyf...                 47452
# 1  Harvardhasadoptedaone-yeartestoptionalpolicyfo...                 42749
# 2  Princetonhasadoptedaone-yeartestoptionalpolicy...                 35370
# 3  Columbiahasadoptedaone-yeartestoptionalpolicyf...                 40203
# 4  Yalehasadoptedaone-yeartestoptionalpolicyforth...                 36844
#
#    Accept Rate  SAT Total 25th Percentile  SAT Total 75th Percentile  \
# ...

# %%
# Let's divide schools in three tiers

# %%
# sat_act_by_college['SAT Tier 1'] = (sat_act_by_college['SAT Total 25th Percentile'] >= x).astype(int)

# %%
sat_act_by_college['SAT Total 25th Percentile'].describe()
# Out:
# count     403.000000
# mean     1168.544665
# std       129.932758
# min       793.000000
# 25%      1070.000000
# 50%      1150.000000
# 75%      1250.000000
# max      1530.000000
# Name: SAT Total 25th Percentile, dtype: float64

# %%
# median between 50% value and max = (1150 + 1530) / 2 = 1340

# %%
sat_act_by_college['SAT Tier 1'] = (sat_act_by_college['SAT Total 25th Percentile'] >= 1340 ).astype(int)

# %%
sat_act_by_college.head()
# Out:
#                 School Test Optional? Applies to Class Year(s)  \
# 0   StanfordUniversity            Yes                     2021
# 1       HarvardCollege            Yes                     2021
# 2  PrincetonUniversity            Yes                     2021
# 3   ColumbiaUniversity            Yes                     2021
# 4       YaleUniversity            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanfordhasadoptedaone-yeartestoptionalpolicyf...                 47452
# 1  Harvardhasadoptedaone-yeartestoptionalpolicyfo...                 42749
# 2  Princetonhasadoptedaone-yeartestoptionalpolicy...                 35370
# 3  Columbiahasadoptedaone-yeartestoptionalpolicyf...                 40203
# 4  Yalehasadoptedaone-yeartestoptionalpolicyforth...                 36844
#
#    Accept Rate  SAT Total 25th Percentile  SAT Total 75th Percentile  \
# ...

# %%
def dummy_tier_2(s):
    if ([sat_act_by_college['SAT Total 25th Percentile'] < 1250]) and ([sat_act_by_college['SAT Total 25th Percentile'] >= 1150]):
        return 1
    else:
        return 0

# %%
sat_act_by_college['SAT Tier 2'] = sat_act_by_college.apply(dummy_tier_2, axis=1)

# %%
sat_act_by_college.head()
# Out:
#                 School Test Optional? Applies to Class Year(s)  \
# 0   StanfordUniversity            Yes                     2021
# 1       HarvardCollege            Yes                     2021
# 2  PrincetonUniversity            Yes                     2021
# 3   ColumbiaUniversity            Yes                     2021
# 4       YaleUniversity            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanfordhasadoptedaone-yeartestoptionalpolicyf...                 47452
# 1  Harvardhasadoptedaone-yeartestoptionalpolicyfo...                 42749
# 2  Princetonhasadoptedaone-yeartestoptionalpolicy...                 35370
# 3  Columbiahasadoptedaone-yeartestoptionalpolicyf...                 40203
# 4  Yalehasadoptedaone-yeartestoptionalpolicyforth...                 36844
#
#    Accept Rate  SAT Total 25th Percentile  SAT Total 75th Percentile  \
# ...

# %%
sat_act_by_college.drop('SAT Tier 2' , axis = 1 , inplace=True)

# %%
sat_act_by_college['SAT Tier 3'] = (sat_act_by_college['SAT Total 25th Percentile'] < 1150 ).astype(int)

# %%
sat_act_by_college.head()
# Out:
#                 School Test Optional? Applies to Class Year(s)  \
# 0   StanfordUniversity            Yes                     2021
# 1       HarvardCollege            Yes                     2021
# 2  PrincetonUniversity            Yes                     2021
# 3   ColumbiaUniversity            Yes                     2021
# 4       YaleUniversity            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanfordhasadoptedaone-yeartestoptionalpolicyf...                 47452
# 1  Harvardhasadoptedaone-yeartestoptionalpolicyfo...                 42749
# 2  Princetonhasadoptedaone-yeartestoptionalpolicy...                 35370
# 3  Columbiahasadoptedaone-yeartestoptionalpolicyf...                 40203
# 4  Yalehasadoptedaone-yeartestoptionalpolicyforth...                 36844
#
#    Accept Rate  SAT Total 25th Percentile  SAT Total 75th Percentile  \
# ...

# %%
Tier_2_dummy = [
    (sat_act_by_college['SAT Tier 1'] == 0) & (sat_act_by_college['SAT Tier 3'] == 0)]

# %%
choices = [1]

# %%
sat_act_by_college['SAT Tier 2'] = np.select(Tier_2_dummy, choices, default=0)

# %%
# https://www.codegrepper.com/code-examples/python/pandas+create+new+column+conditional+on+other+columns

# %%
sat_act_by_college.head(20)
# Out:
#                                 School Test Optional?  \
# 0                   StanfordUniversity            Yes
# 1                       HarvardCollege            Yes
# 2                  PrincetonUniversity            Yes
# 3                   ColumbiaUniversity            Yes
# 4                       YaleUniversity            Yes
# 5      CaliforniaInstituteofTechnology        Yes(TB)
# 6   MassachusettsInstituteofTechnology            Yes
# 7                      BrownUniversity            Yes
# 8                  UniversityofChicago            Yes
# 9                        PomonaCollege            Yes
# 10            UniversityofPennsylvania            Yes
# 11                    DartmouthCollege            Yes
# 12                      BowdoinCollege            Yes
# 13                      DukeUniversity            Yes
# 14                   SwarthmoreCollege            Yes
# 15              NorthwesternUniversity            Yes
# ...

# %%
# Let's do some visualization real quick !!

# %%
new_column_tier = [
    (sat_act_by_college['SAT Tier 1'] == 1) , (sat_act_by_college['SAT Tier 2'] == 1) ,(sat_act_by_college['SAT Tier 3'] == 1) ]

# %%
choices_2 = ['Tier 1', 'Tier 2', 'Tier 3']

# %%
sat_act_by_college['Tier'] = np.select(new_column_tier, choices_2)

# %%
sat_act_by_college.tail(20)
# Out:
#                                    School Test Optional?  \
# 384                      HowardUniversity             No
# 385                FloridaStateUniversity             No
# 386                      HillsdaleCollege             No
# 387            UniversityofCentralFlorida             No
# 388                   UniversityofFlorida             No
# 389              UniversityofSouthFlorida             No
# 390                   GallaudetUniversity             No
# 391                  FloridaInternational             No
# 392                      MorehouseCollege             No
# 393                   UniversityofAlabama             No
# 394          FloridaInstituteofTechnology             No
# 395  LouisianaStateUniversity—​BatonRouge             No
# 396                            TheCitadel             No
# 397                   NewCollegeofFlorida             No
# 398                  ThomasAquinasCollege             No
# ...

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data = sat_act_by_college , x = 'Tier')
plt.title('Number of Colleges per Tier', fontsize=20);

# %%
# As seen above, There are fewer tier 1 colleges and more tier 3 colleges than the rest.

# %%
plt.figure(figsize=(12, 8))
plt.scatter( sat_act_by_college['Accept Rate'], sat_act_by_college['Number of Applicants'], color = "red")
plt.title('Acceptance Rate vs Number of Applicants', fontsize=20)
plt.ylabel('Number of Applicants', fontsize = 15)
plt.xlabel('Acceptance rate', fontsize = 15);

# %%
# As seen above, the number of applicants is concentrated where the acceptance rate is higher but
# the highest number of applicants choose the most difficult colleges to get into, with lower acceptance rate.

# %%
act_2019.head()
# Out:
#         State Participation  Composite  date
# 0     Alabama          100%       18.9  2019
# 1      Alaska           38%       20.1  2019
# 2     Arizona           73%       19.0  2019
# 3    Arkansas          100%       19.3  2019
# 4  California           23%       22.6  2019

# %%
plt.figure(figsize=(18, 12))
plt.ylabel('ACT Composite Score', fontsize = 15)
plt.bar(act_2019['State'], act_2019['Composite'])
plt.title('2019 Nationwide Distribution of Composite ACT Scores', fontsize = 20)
plt.xticks(rotation=80);

# %%
# The average ACT composite score in 2019 is :

# %%
act_2019['Composite'].mean()
# Out:
# 21.449999999999992

# %%
# around 21; the grade each student should aim at a minimum

# %%
plt.figure(figsize=(18, 12))
plt.ylabel('SAT Score', fontsize = 15)
plt.bar(sat_2019['State'], sat_2019['Total'])
plt.title('2019 Nationwide Distribution of Total SAT Scores', fontsize = 20)
plt.xticks(rotation=80);

# %%
sat_2019['Total'].mean()
# Out:
# 1113.078431372549

# %%
# Each student should aim for a total grade of 1113 at a minimum for the SAT !

# %%
intended_college_major.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IntendedCollegeMajor  38 non-null     object
#  1   TestTakers            38 non-null     object
#  2   Percent               38 non-null     object
#  3   Total                 38 non-null     int64
#  4   ReadingWriting        38 non-null     int64
#  5   Math                  38 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1.9+ KB

# %%
intended_college_major['TestTakers'].replace(',','',regex=True, inplace = True)

# %%
intended_college_major['TestTakers'] = intended_college_major['TestTakers'].astype(int)

# %%
popular_majors = intended_college_major.sort_values('TestTakers', ascending=False).head(10)

# %%
plt.figure(figsize=(12, 6))
plt.xlabel('Number of Applicants', fontsize = 12)
plt.barh(popular_majors['IntendedCollegeMajor'], popular_majors['TestTakers'])
plt.title('Top Ten Intended Majors', fontsize = 20);

# %%
intended_college_major['TestTakers'].sum()
# Out:
# 1838991

# %%
popular_majors['TestTakers'].sum()
# Out:
# 1455512

# %%
1455512/1838991
# Out:
# 0.7914731502220511

# %%
#  the top ten intended Majors account for 79% of the test takers !!!

# %%
# Let's output all the files !!

# %%
pwd
# Out:
# '/Users/jo./projects/dsi/projects/project_1'

# %%
path = '/Users/jo./projects/dsi/projects/project_1/output'

# %%
import os

# %%
os.mkdir(path)

# %%
act_scores.to_csv('output/act_scores', index=False)

# %%
sat_scores.to_csv('output/sat_scores', index=False)

# %%
sat_2019.to_csv('output/sat_2019', index=False)

# %%
act_2019.to_csv('output/act_2019', index=False)

# %%
intended_college_major.to_csv('output/intended_college_major', index=False)

# %%
sat_act_by_college.to_csv('output/sat_act_by_college', index=False)
